# %%
import sys
sys.path.append('..')
from dataset import sequence
import numpy as np

(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt',seed=1984)

chr_to_id, id_to_chr = sequence.get_vocab()

print(x_train.shape, t_train.shape)
print(x_test.shape, t_test.shape)

print(x_train[0])
print(t_train[0])

print(''.join([id_to_chr[c] for c in x_train[0]]))  
print(''.join([id_to_chr[c] for c in t_train[0]]))
# Out:
# (45000, 7) (45000, 5)
# (5000, 7) (5000, 5)
# [ 3  0  2  0  0 11  5]
# [ 6  0 11  7  5]
# 71+118
# _189

# %%
class Encoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')

        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=False)
        
        self.params = self.embed.params + self.lstm.params
        self.grads = self.embed.grads + self.lstm.grads
        self.hs = None

    def forward(self, xs):
        xs = self.embed.forward(xs)
        hs = self.lstm.forward(xs)
        self.hs = hs
        return hs[:, -1, :]
    
    def backward(self, dh):
        dhs = np.zeros_like(self.hs)
        dhs[:, -1, :] = dh

        dout = self.lstm.backward(dhs)
        dout = self.embed.backward(dout)
        return dout

# %%
class Decoder:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn

        embed_W = (rn(V, D) / 100).astype('f')
        lstm_Wx = (rn(D, 4 * H) / np.sqrt(D)).astype('f')
        lstm_Wh = (rn(H, 4 * H) / np.sqrt(H)).astype('f')
        lstm_b = np.zeros(4 * H).astype('f')
        affine_W = (rn(H, V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')


        self.embed = TimeEmbedding(embed_W)
        self.lstm = TimeLSTM(lstm_Wx, lstm_Wh, lstm_b, stateful=True)
        self.affine = TimeAffine(affine_W, affine_b)

        self.params, self.grads = [], []

        for layer in (self.embed, self.lstm, self.affine):
            self.params += layer.params
            self.grads += layer.grads
    
    def forward(self, xs, h):
        self.lstm.set_state(h)

        out = self.embed.forward(xs)
        out = self.lstm.forward(out)
        score = self.affine.forward(out)
        return score

    def backward(self, dscore):
        dout = self.affine.backward(dscore)
        dout = self.lstm.backward(dout)
        dout = self.embed.backward(dout)
        dh = self.lstm.dh
        return dh
    
    def generate(self, h, start_id, sample_size):
        sampled = []
        sample_id = start_id
        self.lstm.set_state(h)

        for _ in range(sample_size):
            x = np.array(sample_id).reshape((1, 1))
            out = self.embed.forward(x)
            out = self.lstm.forward(out)
            score = self.affine.forward(out)

            sample_id = np.argmax(score.flatten())
            sampled.append(int(sample_id))

        return sampled

# %%
from common.base_model import BaseModel
from common.time_layers import *

class Seq2seq(BaseModel):
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        self.encoder = Encoder(V, D, H)
        self.decoder = Decoder(V, D, H)
        self.softmax = TimeSoftmaxWithLoss()

        self.params = self.encoder.params + self.decoder.params
        self.grads = self.encoder.grads + self.decoder.grads

    def forward(self, xs, ts):
        decoder_xs, decoder_ts = ts[:, :-1], ts[:, 1:]

        h = self.encoder.forward(xs)
        score = self.decoder.forward(decoder_xs, h)
        loss = self.softmax.forward(score, decoder_ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.softmax.backward(dout)
        dh = self.decoder.backward(dout)
        dout = self.encoder.backward(dh)
        return dout

    def generate(self, xs, start_id, sample_size):
        h = self.encoder.forward(xs)
        sampled = self.decoder.generate(h, start_id, sample_size)
        return sampled

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
from peeky_seq2seq import PeekySeq2seq

(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]

char_to_id, id_to_char = sequence.get_vocab()

vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []

for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1, batch_size=batch_size, max_grad=max_grad)
    correct_num = 0

    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)
    
    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)

    print('val acc %.3f%%' % (acc * 100))

plt.plot(acc_list)
# Out:
# | epoch 1 |  iter 1 / 351 | time 0[s] | loss 2.57
# | epoch 1 |  iter 21 / 351 | time 0[s] | loss 2.48
# | epoch 1 |  iter 41 / 351 | time 0[s] | loss 2.20
# | epoch 1 |  iter 61 / 351 | time 0[s] | loss 1.99
# | epoch 1 |  iter 81 / 351 | time 0[s] | loss 1.89
# | epoch 1 |  iter 101 / 351 | time 0[s] | loss 1.82
# | epoch 1 |  iter 121 / 351 | time 0[s] | loss 1.82
# | epoch 1 |  iter 141 / 351 | time 1[s] | loss 1.80
# | epoch 1 |  iter 161 / 351 | time 1[s] | loss 1.79
# | epoch 1 |  iter 181 / 351 | time 1[s] | loss 1.78
# | epoch 1 |  iter 201 / 351 | time 1[s] | loss 1.77
# | epoch 1 |  iter 221 / 351 | time 1[s] | loss 1.76
# | epoch 1 |  iter 241 / 351 | time 1[s] | loss 1.76
# | epoch 1 |  iter 261 / 351 | time 2[s] | loss 1.75
# | epoch 1 |  iter 281 / 351 | time 2[s] | loss 1.74
# | epoch 1 |  iter 301 / 351 | time 2[s] | loss 1.74
# | epoch 1 |  iter 321 / 351 | time 2[s] | loss 1.73
# | epoch 1 |  iter 341 / 351 | time 2[s] | loss 1.73
# Q   58+77
# T 162
# ☒ 100
# ---
# Q 461+579
# T 1139
# ☒ 1013
# ---
# Q  48+285
# T 666
# ☒ 102
# ---
# Q   551+8
# T 163
# ☒ 100
# ---
# Q  55+763
# T 422
# ☒ 1023
# ---
# Q 752+006
# T 857
# ☒ 1023
# ---
# Q 292+167
# T 1053
# ☒ 1023
# ---
# Q 795+038
# T 1427
# ☒ 1111
# ---
# Q  838+62
# T 864
# ☒ 102
# ---
# Q  39+341
# T 236
# ☒ 102
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 37
#      35     question, correct = x_test[[i]], t_test[[i]]
#      36     verbose = i < 10
# ---> 37     correct_num += eval_seq2seq(model, question, correct, id_to_char, verbose)
#      39 acc = float(correct_num) / len(x_test)
#      40 acc_list.append(acc)
#
# File ~/Programming/deep-learning-from-scratch-2/ch07/../common/util.py:233, in eval_seq2seq(model, question, correct, id_to_char, verbose, is_reverse)
#     231 start_id = correct[0]
#     232 correct = correct[1:]
# --> 233 guess = model.generate(question, start_id, len(correct))
#     235 # 文字列へ変換
#     236 question = ''.join([id_to_char[int(c)] for c in question.flatten()])
#
# File ~/Programming/deep-learning-from-scratch-2/ch07/seq2seq.py:119, in Seq2seq.generate(self, xs, start_id, sample_size)
#     117 def generate(self, xs, start_id, sample_size):
#     118     h = self.encoder.forward(xs)
# --> 119     sampled = self.decoder.generate(h, start_id, sample_size)
#     120     return sampled
#
# File ~/Programming/deep-learning-from-scratch-2/ch07/peeky_seq2seq.py:72, in PeekyDecoder.generate(self, h, start_id, sample_size)
#      69 out = self.embed.forward(x)
#      71 out = np.concatenate((peeky_h, out), axis=2)
# ---> 72 out = self.lstm.forward(out)
#      73 out = np.concatenate((peeky_h, out), axis=2)
#      74 score = self.affine.forward(out)
#
# File ~/Programming/deep-learning-from-scratch-2/ch07/../common/time_layers.py:193, in TimeLSTM.forward(self, xs)
#     191 for t in range(T):
#     192     layer = LSTM(*self.params)
# --> 193     self.h, self.c = layer.forward(xs[:, t, :], self.h, self.c)
#     194     hs[:, t, :] = self.h
#     196     self.layers.append(layer)
#
# File ~/Programming/deep-learning-from-scratch-2/ch07/../common/time_layers.py:114, in LSTM.forward(self, x, h_prev, c_prev)
#     111 Wx, Wh, b = self.params
#     112 N, H = h_prev.shape
# --> 114 A = np.dot(x, Wx) + np.dot(h_prev, Wh) + b
#     116 f = A[:, :H]
#     117 g = A[:, H:2*H]
#
# KeyboardInterrupt:
